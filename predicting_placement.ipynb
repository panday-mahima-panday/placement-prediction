# %% [markdown]
# <a href="https://colab.research.google.com/github/panday-mahima-panday/placement-prediction/blob/main/predicting_placement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#        Unnamed: 0        cgpa          iq   placement
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.500000    5.991000  123.580000    0.500000
# std     29.011492    1.143634   39.944198    0.502519
# min      0.000000    3.300000   37.000000    0.000000
# 25%     24.750000    5.075000  101.500000    0.000000
# 50%     49.500000    6.000000  127.500000    0.500000
# 75%     74.250000    6.900000  149.000000    1.000000
# max     99.000000    8.500000  233.000000    1.000000

# %%
df.shape
# Out:
# (100, 4)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.1)

# %%
x_test
# Out:
#     cgpa     iq
# 77   7.3   50.0
# 76   4.9  155.0
# 52   7.0  175.0
# 3    7.4  132.0
# 40   4.9  134.0
# 22   4.9  120.0
# 21   7.1  151.0
# 58   8.0   79.0
# 87   5.7  132.0
# 39   4.6  146.0

# %%
x_train
# Out:
#     cgpa     iq
# 92   5.2  110.0
# 45   6.0   66.0
# 59   4.8  112.0
# 33   6.0  149.0
# 91   7.5  158.0
# ..   ...    ...
# 13   6.4  116.0
# 89   4.9  151.0
# 68   4.0   75.0
# 44   7.5   61.0
# 11   6.9  138.0
#
# [90 rows x 2 columns]

# %%
y_test
# Out:
# 77    1
# 76    0
# 52    1
# 3     1
# 40    0
# 22    0
# 21    1
# 58    1
# 87    1
# 39    0
# Name: placement, dtype: int64

# %%
y_test
# Out:
# 77    1
# 76    0
# 52    1
# 3     1
# 40    0
# 22    0
# 21    1
# 58    1
# 87    1
# 39    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.68455639, -0.32731089],
#        [ 0.02667103, -1.42203313],
#        [-1.04017009, -0.27755079],
#        [ 0.02667103,  0.64301109],
#        [ 1.36022243,  0.86693155],
#        [-0.77345981,  1.31477247],
#        [ 0.47118816,  0.91669165],
#        [ 1.44912586, -0.84979196],
#        [ 0.38228474,  0.44397069],
#        [ 0.11557445, -1.44691318],
#        [ 0.9157053 ,  0.39421058],
#        [ 0.47118816, -2.14355461],
#        [ 0.64899502,  1.46405277],
#        [-0.59565296, -0.05363033],
#        [ 0.73789844, -0.82491191],
#        [-0.50674953, -0.40195104],
#        [-0.77345981, -1.42203313],
#        [-1.12907352, -0.05363033],
#        [ 0.29338131, -0.50147125],
#        [-1.12907352, -0.89955206],
#        [ 2.07144985,  1.11573206],
#        [-0.86236324, -0.80003186],
#        [-0.15113583,  0.46885074],
#        [-0.50674953,  0.39421058],
#        [ 0.29338131,  0.12053002],
#        [-0.50674953,  0.29469038],
#        [ 0.73789844,  0.44397069],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 1.18241558, -1.82011395],
#        [-0.95126667,  0.7922914 ],
#        [ 0.9157053 ,  1.28989242],
#        [ 1.271319  ,  0.22005023],
#        [-0.95126667,  0.26981033],
#        [-0.95126667, -0.07851038],
#        [ 1.00460872,  0.6927712 ],
#        [ 1.80473956, -1.09859247],
#        [-0.24003925,  0.22005023],
#        [-1.21797695,  0.56837094]])

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
y_test
# Out:
# 77    1
# 76    0
# 52    1
# 3     1
# 40    0
# 22    0
# 21    1
# 58    1
# 87    1
# 39    0
# Name: placement, dtype: int64

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
